# %% [markdown]
# Python programlama dilinde print komutu ekrandan  kulanıcıya bilgi veren bir koddur.
# 06.08.2024-VERİ YAPILARI VE ALGORİTMA DERSİ 1
# İGÜ İSTKA SİBER AKADEMİ MERKEZİ

# %%
print("Merhaba,iGÜ-İSTKA!") # print  ekrana çıktı veren bir koddur.
# Out:
# Merhaba,iGÜ-İSTKA!

# %%
import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod  bloğudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %% [markdown]
# sys bir kütüphanedir

# %%
from google.colab import drive # google  colab -
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pvd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /bin/bash: line 1: pvd: command not found
